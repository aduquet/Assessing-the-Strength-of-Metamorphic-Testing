# %%
import json
import glob as gl
import os
import pathlib
import math
import pandas as pd

# %%
target_path = 'SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr1_mul_unmutated.json'
target_paths = ['/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr1_mul_unmutated.json']
final_results = []
for paths in target_paths:
    mutated_file_name = paths.split('/')[-1]
    # target_file = os.path.join(paths, 'gmr1_mul.json')
    problems = []
    try:
        with open(paths, 'r') as file:
            mr1 = json.load(file)

        cnt_v_scaled = 0
        cnt_no_v_scaled = 0
        otro_scaled = 0
        status_scaled = []
        
        cnt_v_g = 0
        cnt_no_v_g = 0
        otro_g = 0
        status_g = []
        
        cnt_v_l = 0
        cnt_no_v_l  = 0
        otro_l= 0
        status_l = []
        
        cnt_v_e = 0
        cnt_no_v_e = 0
        otro_e = 0
        status_e = []
        
        for key, value in mr1.items():
            try:
                if value['vs_gmr_mul_scaled'] == "no-violated":
                    cnt_no_v_scaled += 1
                
                elif value['vs_gmr_mul_scaled'] == "violated":
                    cnt_v_scaled += 1
                else:
                    otro_scaled += 1
                # status.append('All good')
            except :
                status_scaled.append('ID NOT FOUNT/PROBLEMS ->' + key)
        
 
            try:
                if value['vs_gmr_mul_g'] == "no-violated":
                    cnt_no_v_g += 1
                
                elif value['vs_gmr_mul_g'] == "violated":
                    cnt_v_g += 1
                else:
                    otro_scaled += 1
                # status.append('All good')
            except :
                status_g.append('ID NOT FOUNT/PROBLEMS ->' + key)
                
            try:
                if value['vs_gmr_mul_l'] == "no-violated":
                    cnt_no_v_l += 1
                
                elif value['vs_gmr_mul_l'] == "violated":
                    cnt_v_l += 1
                else:
                    otro_l += 1
                # status.append('All good')
            except :
                status_scaled.append('ID NOT FOUNT/PROBLEMS ->' + key)
                
            try:
                if value['vs_gmr_mul_e'] == "no-violated":
                    cnt_no_v_e += 1
                
                elif value['vs_gmr_mul_e'] == "violated":
                    cnt_v_e+= 1
                else:
                    otro_e += 1
                # status.append('All good')
            except :
                status_scaled.append('ID NOT FOUNT/PROBLEMS ->' + key)       
        final_file = {
            'file_name': mutated_file_name, 
            'cnt_no_v_scaled': cnt_no_v_scaled,
            'cnt_v_scaled': cnt_v_scaled,
            'otro_scaled': otro_scaled,
            'status_scaled': status_scaled,
            'cnt_no_v_g': cnt_no_v_g,
            'cnt_v_g': cnt_v_g,
            'otro_g': otro_g,
            'status_g': status_g,
            'cnt_no_v_l': cnt_no_v_l,
            'cnt_v_l': cnt_v_l,
            'otro_l': otro_l,
            'status_l': status_l,
            'cnt_no_v_e': cnt_no_v_e,
            'cnt_v_e': cnt_v_e,
            'otro_e': otro_e,
            'status_e': status_e
            }
        
        final_results.append(final_file)
        print(final_results)
        
    except :
        problems.append('File not found ->  ' + mutated_file_name)
df_final_results = pd.DataFrame(final_results)
# Save the DataFrame to a CSV file
df_final_results.to_csv('analysis_v_nv_GMR1_unmutated.csv')
# with open('analysis_v_nv_MR1.json', 'w') as json_file:
#     json.dump(final_results, json_file, indent=4)
# Out:
# [{'file_name': 'gmr1_mul_unmutated.json', 'cnt_no_v_scaled': 193, 'cnt_v_scaled': 2, 'otro_scaled': 0, 'status_scaled': [], 'cnt_no_v_g': 194, 'cnt_v_g': 1, 'otro_g': 0, 'status_g': [], 'cnt_no_v_l': 0, 'cnt_v_l': 195, 'otro_l': 0, 'status_l': [], 'cnt_no_v_e': 0, 'cnt_v_e': 195, 'otro_e': 0, 'status_e': []}]

# %%
target_path = 'SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr1_mul_unmutated.json'
target_paths = ['/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr2_exc_unmutated.json']
final_results = []
for paths in target_paths:
    mutated_file_name = paths.split('/')[-1]
    # print(mutated_file_name)
    problems = []
    try:
        with open(paths, 'r') as file:
            mr1 = json.load(file)
        
        cnt_v_g = 0
        cnt_no_v_g = 0
        otro_g = 0
        status_g = []
        
        cnt_v_l = 0
        cnt_no_v_l  = 0
        otro_l= 0
        status_l = []
        
        cnt_v_e = 0
        cnt_no_v_e = 0
        otro_e = 0
        status_e = []
        
        for key, value in mr1.items():
        
 
            try:
                if value['vs_gmr_exc_g'] == "no-violated":
                    cnt_no_v_g += 1
                
                elif value['vs_gmr_exc_g'] == "violated":
                    cnt_v_g += 1
                else:
                    otro_g += 1
                # status.append('All good')
            except :
                status_g.append('ID NOT FOUNT/PROBLEMS ->' + key)
                
            try:
                if value['vs_gmr_exc_l'] == "no-violated":
                    cnt_no_v_l += 1
                
                elif value['vs_gmr_exc_l'] == "violated":
                    cnt_v_l += 1
                else:
                    otro_l += 1
                # status.append('All good')
            except :
                status_l.append('ID NOT FOUNT/PROBLEMS ->' + key)
                
            try:
                if value['vs_gmr_exc_e'] == "no-violated":
                    cnt_no_v_e += 1
                
                elif value['vs_gmr_exc_e'] == "violated":
                    cnt_v_e+= 1
                else:
                    otro_e += 1
                # status.append('All good')
            except :
                status_e.append('ID NOT FOUNT/PROBLEMS ->' + key)       
        final_file = {
            'file_name': mutated_file_name, 
            'cnt_no_v_g': cnt_no_v_g,
            'cnt_v_g': cnt_v_g,
            'otro_g': otro_g,
            'status_g': status_g,
            'cnt_no_v_l': cnt_no_v_l,
            'cnt_v_l': cnt_v_l,
            'otro_l': otro_l,
            'status_l': status_l,
            'cnt_no_v_e': cnt_no_v_e,
            'cnt_v_e': cnt_v_e,
            'otro_e': otro_e,
            'status_e': status_e
            }
        
        final_results.append(final_file)
        
    except :
        problems.append('File not found ->  ' + mutated_file_name)
df_final_results = pd.DataFrame(final_results)
# Save the DataFrame to a CSV file
df_final_results.to_csv('analysis_v_nv_GMR2_unmutated.csv')
# with open('analysis_v_nv_MR1.json', 'w') as json_file:
#     json.dump(final_results, json_file, indent=4)

# %%
target_path = 'SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr1_mul_unmutated.json'
target_paths = ['/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr3_inc_unmutated.json']
final_results = []
for paths in target_paths:
    mutated_file_name = paths.split('/')[-1]
    # print(mutated_file_name)
    problems = []
    try:
        with open(paths, 'r') as file:
            mr1 = json.load(file)
        
        cnt_v_g = 0
        cnt_no_v_g = 0
        otro_g = 0
        status_g = []
        
        cnt_v_l = 0
        cnt_no_v_l  = 0
        otro_l= 0
        status_l = []
        
        cnt_v_e = 0
        cnt_no_v_e = 0
        otro_e = 0
        status_e = []
        
        for key, value in mr1.items():
        
 
            try:
                if value['vs_gmr_inc_g'] == "no-violated":
                    cnt_no_v_g += 1
                
                elif value['vs_gmr_inc_g'] == "violated":
                    cnt_v_g += 1
                else:
                    otro_g += 1
                # status.append('All good')
            except :
                status_g.append('ID NOT FOUNT/PROBLEMS ->' + key)
                
            try:
                if value['vs_gmr_inc_l'] == "no-violated":
                    cnt_no_v_l += 1
                
                elif value['vs_gmr_inc_l'] == "violated":
                    cnt_v_l += 1
                else:
                    otro_l += 1
                # status.append('All good')
            except :
                status_l.append('ID NOT FOUNT/PROBLEMS ->' + key)
                
            try:
                if value['vs_gmr_inc_e'] == "no-violated":
                    cnt_no_v_e += 1
                
                elif value['vs_gmr_inc_e'] == "violated":
                    cnt_v_e+= 1
                else:
                    otro_e += 1
                # status.append('All good')
            except :
                status_e.append('ID NOT FOUNT/PROBLEMS ->' + key)       
        final_file = {
            'file_name': mutated_file_name, 
            'cnt_no_v_g': cnt_no_v_g,
            'cnt_v_g': cnt_v_g,
            'otro_g': otro_g,
            'status_g': status_g,
            'cnt_no_v_l': cnt_no_v_l,
            'cnt_v_l': cnt_v_l,
            'otro_l': otro_l,
            'status_l': status_l,
            'cnt_no_v_e': cnt_no_v_e,
            'cnt_v_e': cnt_v_e,
            'otro_e': otro_e,
            'status_e': status_e
            }
        
        final_results.append(final_file)
        
    except :
        problems.append('File not found ->  ' + mutated_file_name)
df_final_results = pd.DataFrame(final_results)
# Save the DataFrame to a CSV file
df_final_results.to_csv('analysis_v_nv_GMR3_unmutated.csv')
# with open('analysis_v_nv_MR1.json', 'w') as json_file:
#     json.dump(final_results, json_file, indent=4)

# %%
target_path = 'SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr1_mul_unmutated.json'
target_paths = ['/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr4_inv_unmutated.json']
final_results = []
for paths in target_paths:
    mutated_file_name = paths.split('/')[-1]
    # print(mutated_file_name)
    problems = []
    try:
        with open(paths, 'r') as file:
            mr1 = json.load(file)
        
        cnt_v_g = 0
        cnt_no_v_g = 0
        otro_g = 0
        status_g = []
        
        cnt_v_l = 0
        cnt_no_v_l  = 0
        otro_l= 0
        status_l = []
        
        cnt_v_e = 0
        cnt_no_v_e = 0
        otro_e = 0
        status_e = []
        
        for key, value in mr1.items():
        
 
            try:
                if value['vs_gmr_inv_g'] == "no-violated":
                    cnt_no_v_g += 1
                
                elif value['vs_gmr_inv_g'] == "violated":
                    cnt_v_g += 1
                else:
                    otro_g += 1
                # status.append('All good')
            except :
                status_g.append('ID NOT FOUNT/PROBLEMS ->' + key)
                
            try:
                if value['vs_gmr_inv_l'] == "no-violated":
                    cnt_no_v_l += 1
                
                elif value['vs_gmr_inv_l'] == "violated":
                    cnt_v_l += 1
                else:
                    otro_l += 1
                # status.append('All good')
            except :
                status_l.append('ID NOT FOUNT/PROBLEMS ->' + key)
                
            try:
                if value['vs_gmr_inv_e'] == "no-violated":
                    cnt_no_v_e += 1
                
                elif value['vs_gmr_inv_e'] == "violated":
                    cnt_v_e+= 1
                else:
                    otro_e += 1
                # status.append('All good')
            except :
                status_e.append('ID NOT FOUNT/PROBLEMS ->' + key)       
        final_file = {
            'file_name': mutated_file_name, 
            'cnt_no_v_g': cnt_no_v_g,
            'cnt_v_g': cnt_v_g,
            'otro_g': otro_g,
            'status_g': status_g,
            'cnt_no_v_l': cnt_no_v_l,
            'cnt_v_l': cnt_v_l,
            'otro_l': otro_l,
            'status_l': status_l,
            'cnt_no_v_e': cnt_no_v_e,
            'cnt_v_e': cnt_v_e,
            'otro_e': otro_e,
            'status_e': status_e
            }
        
        final_results.append(final_file)
        
    except :
        problems.append('File not found ->  ' + mutated_file_name)
df_final_results = pd.DataFrame(final_results)
# Save the DataFrame to a CSV file
df_final_results.to_csv('analysis_v_nv_GMR4_unmutated.csv')
# with open('analysis_v_nv_MR1.json', 'w') as json_file:
#     json.dump(final_results, json_file, indent=4)

# %%
target_path = 'SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr1_mul_unmutated.json'
target_paths = ['/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr5_ref_unmutated.json']
final_results = []
for paths in target_paths:
    mutated_file_name = paths.split('/')[-1]
    # print(mutated_file_name)
    problems = []
    try:
        with open(paths, 'r') as file:
            mr1 = json.load(file)
        
        cnt_v_g = 0
        cnt_no_v_g = 0
        otro_g = 0
        status_g = []
        
        for key, value in mr1.items():
        
 
            try:
                if value['vs_gmr_ref'] == "no-violated":
                    cnt_no_v_g += 1
                
                elif value['vs_gmr_ref'] == "violated":
                    cnt_v_g += 1
                else:
                    otro_g += 1
                # status.append('All good')
            except :
                status_g.append('ID NOT FOUNT/PROBLEMS ->' + key)
                
             
        final_file = {
            'file_name': mutated_file_name, 
            'cnt_no_v': cnt_no_v_g,
            'cnt_v': cnt_v_g,
            'otro': otro_g,
            'status': status_g,

            }
        
        final_results.append(final_file)
        
    except :
        problems.append('File not found ->  ' + mutated_file_name)
df_final_results = pd.DataFrame(final_results)
# Save the DataFrame to a CSV file
df_final_results.to_csv('analysis_v_nv_GMR5_unmutated.csv')
# with open('analysis_v_nv_MR1.json', 'w') as json_file:
#     json.dump(final_results, json_file, indent=4)

# %%
target_path = 'SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr1_mul_unmutated.json'
target_paths = ['/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/gmr6_dupli_unmutated.json']
final_results = []
for paths in target_paths:
    mutated_file_name = paths.split('/')[-1]
    # print(mutated_file_name)
    problems = []
    try:
        with open(paths, 'r') as file:
            mr1 = json.load(file)
        
        cnt_v_g = 0
        cnt_no_v_g = 0
        otro_g = 0
        status_g = []
        
        cnt_v_l = 0
        cnt_no_v_l  = 0
        otro_l= 0
        status_l = []
        
        cnt_v_e = 0
        cnt_no_v_e = 0
        otro_e = 0
        status_e = []
        
        for key, value in mr1.items():
        
 
            try:
                if value['vs_gmr_dupli_g'] == "no-violated":
                    cnt_no_v_g += 1
                
                elif value['vs_gmr_dupli_g'] == "violated":
                    cnt_v_g += 1
                else:
                    otro_g += 1
                # status.append('All good')
            except :
                status_g.append('ID NOT FOUNT/PROBLEMS ->' + key)
                
            try:
                if value['vs_gmr_dupli_l'] == "no-violated":
                    cnt_no_v_l += 1
                
                elif value['vs_gmr_dupli_l'] == "violated":
                    cnt_v_l += 1
                else:
                    otro_l += 1
                # status.append('All good')
            except :
                status_l.append('ID NOT FOUNT/PROBLEMS ->' + key)
                
            try:
                if value['vs_gmr_dupli_e'] == "no-violated":
                    cnt_no_v_e += 1
                
                elif value['vs_gmr_dupli_e'] == "violated":
                    cnt_v_e+= 1
                else:
                    otro_e += 1
                # status.append('All good')
            except :
                status_e.append('ID NOT FOUNT/PROBLEMS ->' + key)       
        final_file = {
            'file_name': mutated_file_name, 
            'cnt_no_v_g': cnt_no_v_g,
            'cnt_v_g': cnt_v_g,
            'otro_g': otro_g,
            'status_g': status_g,
            'cnt_no_v_l': cnt_no_v_l,
            'cnt_v_l': cnt_v_l,
            'otro_l': otro_l,
            'status_l': status_l,
            'cnt_no_v_e': cnt_no_v_e,
            'cnt_v_e': cnt_v_e,
            'otro_e': otro_e,
            'status_e': status_e
            }
        
        final_results.append(final_file)
        
    except :
        problems.append('File not found ->  ' + mutated_file_name)
df_final_results = pd.DataFrame(final_results)
# Save the DataFrame to a CSV file
df_final_results.to_csv('analysis_v_nv_GMR6_unmutated.csv')
# with open('analysis_v_nv_MR1.json', 'w') as json_file:
#     json.dump(final_results, json_file, indent=4)

# %%
final_file
# Out:
# {'file_name': 'gmr6_dupli_unmutated.json',
#  'cnt_no_v_g': 49,
#  'cnt_v_g': 146,
#  'otro_g': 0,
#  'status_g': [],
#  'cnt_no_v_l': 45,
#  'cnt_v_l': 150,
#  'otro_l': 0,
#  'status_l': [],
#  'cnt_no_v_e': 56,
#  'cnt_v_e': 139,
#  'otro_e': 0,
#  'status_e': []}

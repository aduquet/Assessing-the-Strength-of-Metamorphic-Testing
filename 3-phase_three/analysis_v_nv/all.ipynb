# %%
import pandas as pd
import json

# %%
mutant_id = '/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/mutants_id.csv'
hmr_one = '/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/analysis_v_nv_MR1.csv'
hmr_two = '/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/analysis_v_nv_MR2.csv'
hmr_three = '/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/analysis_v_nv_HMR3.csv'

gmr1 = '/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/analysis_v_nv_GMR1.csv'
gmr2 = '/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/analysis_v_nv_GMR2.csv'
gmr3 = '/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/analysis_v_nv_GMR3.csv'
gmr4 = '/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/analysis_v_nv_GMR4.csv'
gmr5 = '/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/analysis_v_nv_GMR5.csv'
gmr6 = '/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/analysis_v_nv/analysis_v_nv_GMR6.csv'

equi_mutants = '/Users/alduck/Documents/Github/mt_industrial_usecase/a4_all_true.csv'

# %%
df_mutant_id = pd.read_csv(mutant_id)
df_equ_mut = pd.read_csv(equi_mutants, index_col=0)
df_hmr_1 = pd.read_csv(hmr_one, index_col=0)
df_hmr_2 = pd.read_csv(hmr_two, index_col=0)
df_hmr_3 = pd.read_csv(hmr_three, index_col=0)

df_gmr_1 = pd.read_csv(gmr1, index_col=0)
df_gmr_2 = pd.read_csv(gmr2, index_col=0)
df_gmr_3 = pd.read_csv(gmr3, index_col=0)
df_gmr_4 = pd.read_csv(gmr4, index_col=0)
df_gmr_5 = pd.read_csv(gmr5, index_col=0)
df_gmr_6 = pd.read_csv(gmr6, index_col=0)

# %%
df_hmr_1
# Out:
#                 file_name  cnt_no_v  cnt_v  otro status
# 0        Num84Line13Vers2       195      0     0     []
# 1      Num232Line16Vers38       195      0     0     []
# 2    Num1230Line139Vers15       195      0     0     []
# 3        Num46Line10Vers7       195      0     0     []
# 4      Num117Line13Vers35       195      0     0     []
# ..                    ...       ...    ...   ...    ...
# 400   Num1300Line143Vers2       195      0     0     []
# 401    Num283Line20Vers34       195      0     0     []
# 402     Num158Line15Vers2       195      0     0     []
# 403     Num61Line11Vers15       195      0     0     []
# 404    Num143Line14Vers24       195      0     0     []
#
# [405 rows x 5 columns]

# %%
equi_mutants = list(df_equ_mut['mutant_ID'])
print(equi_mutants)
# Out:
# ['Num84Line13Vers2', 'Num232Line16Vers38', 'Num1230Line139Vers15', 'Num117Line13Vers35', 'Num161Line15Vers5', 'Num192Line15Vers36', 'Num1297Line141Vers9', 'Num113Line13Vers31', 'Num253Line20Vers4', 'Num108Line13Vers26', 'Num1309Line144Vers8', 'Num165Line15Vers9', 'Num105Line13Vers23', 'Num179Line15Vers23', 'Num292Line20Vers43', 'Num678Line88Vers8', 'Num1304Line144Vers3', 'Num810Line104Vers11', 'Num266Line20Vers17', 'Num248Line19Vers8', 'Num1111Line119Vers1', 'Num1293Line141Vers5', 'Num262Line20Vers13', 'Num216Line16Vers22', 'Num91Line13Vers9', 'Num202Line16Vers8', 'Num101Line13Vers19', 'Num280Line20Vers31', 'Num139Line14Vers20', 'Num187Line15Vers31', 'Num144Line14Vers25', 'Num220Line16Vers26', 'Num379Line41Vers23', 'Num284Line20Vers35', 'Num23Line8Vers10', 'Num140Line14Vers21', 'Num111Line13Vers29', 'Num58Line11Vers12', 'Num1310Line144Vers9', 'Num78Line11Vers32', 'Num682Line88Vers12', 'Num674Line88Vers4', 'Num153Line14Vers34', 'Num1240Line139Vers25', 'Num226Line16Vers32', 'Num276Line
# ...

# %%
final_results = []
status_hmr1 = []
status_hmr2 = []
status_hmr3 = []

hmr1_v = 0
hmr1_nv = 0
hmr1_otro = 0
        
hmr2_v = 0
hmr2_nv = 0
hmr2_otro = 0

hmr3_v = 0
hmr3_nv = 0
hmr3_otro = 0

for index, row in df_mutant_id.iterrows():
    if row['file_name'] in equi_mutants:
        mutat_status = 'eqv/surv'
    else:
        mutat_status = 'killed'
        
    try:
        hmr1_v = df_hmr_1.loc[df_hmr_1['file_name'] == row['file_name'], 'cnt_v'].iloc[0]

        
        hmr1_nv = df_hmr_1.loc[df_hmr_1['file_name'] == row['file_name'], 'cnt_no_v'].iloc[0]
        
        hmr1_otro = df_hmr_1.loc[df_hmr_1['file_name'] == row['file_name'], 'cnt_otro'].iloc[0]
    except:
        status_hmr1.append('id not found ->' + row['file_name'])
    
    try:
        hmr2_v =  df_hmr_2.loc[df_hmr_2['file_name'] == row['file_name'], 'cnt_v'].iloc[0]
        hmr2_nv = df_hmr_2.loc[df_hmr_2['file_name'] == row['file_name'], 'cnt_no_v'].iloc[0]
        hmr2_otro = df_hmr_2.loc[df_hmr_2['file_name'] == row['file_name'], 'cnt_otro'].iloc[0]
        print('*****')
        print(hmr1_nv)
    except:
        status_hmr2.append('id not found ->' + row['file_name'])
        
    try:
        hmr3_v =  df_hmr_3.loc[df_hmr_3['file_name'] == row['file_name'], 'cnt_v'].iloc[0]
        hmr3_nv = df_hmr_3.loc[df_hmr_3['file_name'] == row['file_name'], 'cnt_no_v'].iloc[0]
        hmr3_otro = df_hmr_3.loc[df_hmr_3['file_name'] == row['file_name'], 'cnt_otro'].iloc[0]
    except:
        status_hmr3.append('id not found ->' + row['file_name'])
    
    final = {
       'mutant_id': row['file_name'],
       'HMR1_v': hmr1_v,
       'HMR1_nv': hmr1_nv,
       'HMR1_cr': hmr1_otro,
       'HMR2_v': hmr2_v,
       'HMR2_nv': hmr2_nv,
       'HMR2_cr': hmr2_otro,
       'HMR3_v': hmr3_v,
       'HMR3_nv': hmr3_nv,
       'HMR3_cr': hmr3_otro,
       'mutant_status': mutat_status
       } 
    final_results.append(final)
df_final_results = pd.DataFrame(final_results)
# Save the DataFrame to a CSV file
df_final_results.to_csv('analysis_HMRs.csv')

# %%
path_HMR3 = '/Users/alduck/Documents/Github/mt_industrial_usecase/SpecialIssue_PROFES/MutationAnalisys/Analysis/unmutated_new/MR3_sum_err/Results_MR3Sum_unmutated.json'

with open(path_HMR3, 'r') as file:
    mr3 = json.load(file)

no_v_td = []
v_td=[]
for key, value in mr3.items():
    if value['vs'] == 'violated':
        v_td.append(key)
    else:
        no_v_td.append(key)

final = {
    'no_v_td': no_v_td,
    'v_td': v_td
}

with open('hmr3_td_v_nv.json', 'w') as json_file:
    json.dump(final, json_file, indent = 4 )

# %%
len(no_v_td)
print(no_v_td)
# Out:
# ['x8q6CUrM8evZ5i2MZSmuTyF', 'mpt5sxNXi3ZtuMbWEwTepW', 'aHnRKeJd2osztTy9fkh9Am', 'TNA7oJx2UdQErSeLKuK7fE', 'fPjqNeKg8Y9FytR4jHQMi9', 'jLntuYZDrWcLvC4MJ5v23b', 'SctED2kh5TbqELR9zaVCwj', 'x8KYKfn8tieHKjYkFTJe23w', 'x4qUhjzqKzvKTysxmYtdtvG', 'mPj6cLgddNdt8f7zyHo6mA', 'ZHUo9LALvgNyx8hGQ6xTkg', 'x9Gt4m3ixi6Z2iPgr4S9mZQ', 'a7TVyGyHzB6cy9Ugiw9ubw', 'HNUGfo5en84QZsSUfRVEUh', 'k7oZ58dZ4Xdi3zSZxVafyV', 'x9saWi9wChZ6xzpRWjjw8kP', 'fehxPttF25H2GhXo44NGgu', 'bkmk3hfxU8HRJjkgHEPkRL', 'aHPQQ8RHzbYvv4N5SbmyS9', 'aySNvZ66jzH2QwCwQ6iULY', 'XqwEAJRUts6BNai8oWkA2t', 'THBABTChki8CYZZkjFwWFn', 'x2FZryZG7v5LxgJAaDnaozV', 'x7tRzbZu3xFHe2SZ7DqKzrP', 'MHyUvHTtW6PjkYd5aZEHaj', 'JsP7Bx2LLJFBDy544emtmp', 'x5iXieBpEqDCpMpBY6TThrM', 'KCquU8wqagoA5BKiRayYUR', 'Rw4TPxbauHxuA8jpbDKy5A', 'PZZxL8R8pPy2DbGeMZbzD7', 'x6tYYRZqsfRxDwDz6bKz2wb', 'WvsgREEGeYQh6x9DBymQG6', 'x3WtpMdfxyBZxeuT8kceJVU', 'Gv6C9ys7JhZ7RoL5oMuCoF', 'iyoNkiqBc5GqR5epghv3im', 'ZJBaY2ZaQBAGKxpGKBr4By', 'Kd6gZTQoghnYBiEeJgRooZ', 'AGCXNMCpMdCsra3dsWU2hG',
# ...

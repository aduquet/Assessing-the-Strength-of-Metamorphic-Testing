# %%
import json
import pandas as pd
import glob as gl
import pandas as pd
import matplotlib.pyplot as plt

# %%
main_path = '/Users/alduck/Documents/Github/INFSOF_Paper/3-phase_three/mixed_killed_td/*'
mutant_paths = gl.glob(main_path)

# %%
len(mutant_paths)
# Out:
# 135

# %%
aux_list = []

for paths in mutant_paths:
    folder_name = paths.split('/')[-1]
    
    HMR1_path = paths + '/final_MR1_' + folder_name + '.json'    
    main_df_path = paths + '/is_equal_' + folder_name + '.csv'
    
    with open(HMR1_path, 'r') as file:
        hmr1 = json.load(file)
        
    main_df = pd.read_csv(main_df_path)
    for index, row in main_df.iterrows():
        
        td_id = row['testID']
        
        try:
            if hmr1[td_id]['MR1_status'] == 'no-violated':
                vs = 'nv'
            else:
                vs = 'v'
        except:
            vs = 'testID dont found'
        
        
        if row['is_output_x_equal'] == 'True' and  row['is_output_y_equal'] == 'True' and row['is_int_x_equal'] == 'True' and row['is_int_y_equal'] == 'True':
            mts = 'survived'
        else:
            mts = 'killed'
   
        final = {
            'mutan_id': folder_name,
            'tes_ID': td_id,

                'vs':vs,
                'mutant_status': mts
            
        }
        
        aux_list.append(final)

# %%
aux_list
# Out:
# [{'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'VRfNx3Krud5jD43PHgxJdc',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'SVumrKz2o5MrZ4LmouTKTt',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'x9GsMzyJggmJVBFwtDdWgGy',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'HGG3ZoLQDvNSCo68FfqnyR',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'HrsMvznCqa4BcUSMQxhswN',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'iZ6RWNFtznDcnW86BLoVzz',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'JSoCQLK4JncUyGkTJmBf8U',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'x8q6CUrM8evZ5i2MZSmuTyF',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'grCYYqDppVgYjxEzo9gi8b',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'GXKoJAoFCeMDN9hNHHZJbw',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'DmDYBcDbmmYZFZEFtSzUHf',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'a7JrStTEFDWRVJDJEE8iSi',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'EGeSryitfwa2bo5qB9Z94f',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'x7ametREFiSraNdMc3Su6Sd',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'fumRDcrFqivMfX8wvHsy2i',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'gVMc9vqN7G2m9EYvFDZKVT',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'mpt5sxNXi3ZtuMbWEwTepW',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'aHnRKeJd2osztTy9fkh9Am',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'TNA7oJx2UdQErSeLKuK7fE',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'fPjqNeKg8Y9FytR4jHQMi9',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'jLntuYZDrWcLvC4MJ5v23b',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'kcqGZAaauZU3gHx6LpaaJv',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'SctED2kh5TbqELR9zaVCwj',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'x8KYKfn8tieHKjYkFTJe23w',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'x4qUhjzqKzvKTysxmYtdtvG',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'mPj6cLgddNdt8f7zyHo6mA',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'o9mEQL5eKtK5c8fdjA5e5P',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'x8DL2scNsMvJaGeqBxMWU9n',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'CFPucPcFjWGdGqdpUGTDM9',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'JFyUSoESZtgRLyCpBGPPEZ',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'x748vyTMHhyrecXxanBWjAq',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'ZHUo9LALvgNyx8hGQ6xTkg',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'x9Gt4m3ixi6Z2iPgr4S9mZQ',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'a7TVyGyHzB6cy9Ugiw9ubw',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'HNUGfo5en84QZsSUfRVEUh',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'k7oZ58dZ4Xdi3zSZxVafyV',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'x6q86zD4g8aZbVVqZcdmEDZ',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'x9saWi9wChZ6xzpRWjjw8kP',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'fehxPttF25H2GhXo44NGgu',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': 'bEWNkMUyS9U6X2PDhjFM3d',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num46Line10Vers7',
#   'tes_ID': '

#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  {'mutan_id': 'Num1343Line149Vers2',
#   'tes_ID': 'x4qUhjzqKzvKTysxmYtdtvG',
#   'vs': 'nv',
#   'mutant_status': 'killed'},
#  ...]

# %%
df = pd.DataFrame(aux_list)

# %%
df
# Out:
#                  mutan_id                   tes_ID  vs mutant_status
# 0        Num46Line10Vers7   VRfNx3Krud5jD43PHgxJdc  nv        killed
# 1        Num46Line10Vers7   SVumrKz2o5MrZ4LmouTKTt  nv        killed
# 2        Num46Line10Vers7  x9GsMzyJggmJVBFwtDdWgGy  nv        killed
# 3        Num46Line10Vers7   HGG3ZoLQDvNSCo68FfqnyR  nv        killed
# 4        Num46Line10Vers7   HrsMvznCqa4BcUSMQxhswN  nv        killed
# ...                   ...                      ...  ..           ...
# 26320  Num411Line42Vers14  x4pCU9Zc9sTECRpMRFWG8CP   v        killed
# 26321  Num411Line42Vers14   U5YAs6CFd4CpnrgHSMGz5H   v        killed
# 26322  Num411Line42Vers14   JsL4mnFBXG9PyUsRgK73KM   v        killed
# 26323  Num411Line42Vers14   Cw9zSQNxnMUAPpv63ueZMp  nv        killed
# 26324  Num411Line42Vers14   o42dQv5S9wdSGvQuBCdyuS   v        killed
#
# [26325 rows x 4 columns]

# %%
import json
import pandas as pd

# This dictionary will hold the data with folder_name as keys
data_dict = {}

for paths in mutant_paths:
    folder_name = paths.split('/')[-1]
    
    HMR1_path = paths + '/final_MR1_' + folder_name + '.json'
    main_df_path = paths + '/is_equal_' + folder_name + '.csv'
    
    try:
        with open(HMR1_path, 'r') as file:
            hmr1 = json.load(file)
    except FileNotFoundError:
        print(f"File not found: {HMR1_path}")
        continue
    
    try:
        main_df = pd.read_csv(main_df_path)
    except FileNotFoundError:
        print(f"File not found: {main_df_path}")
        continue
    
    # Initialize an empty dictionary for each folder if not already existing
    if folder_name not in data_dict:
        data_dict[folder_name] = {}
    
    for index, row in main_df.iterrows():
        td_id = row['testID']
        
        vs = hmr1.get(td_id, {}).get('MR1_status', 'testID not found')
        vs = 'nv' if vs == 'no-violated' else 'v' if vs != 'testID not found' else vs
        
        if row['is_output_x_equal'] and row['is_output_y_equal'] and row['is_int_x_equal'] and row['is_int_y_equal']:
            mts = 'survived'
        else:
            mts = 'killed'
   
        # Append data for each test ID into the corresponding folder's dictionary
        data_dict[folder_name][td_id + '_vs'] = vs
        data_dict[folder_name][td_id + '_mutant_status'] = mts

# Convert the dictionary into a DataFrame
# Transpose the result since dict keys will become column headers
final_df = pd.DataFrame.from_dict(data_dict, orient='index')

# Check the DataFrame
print(final_df.head())

# If you need to save or further process `final_df`, you can do so here
# Out:
#                     VRfNx3Krud5jD43PHgxJdc_vs  \
# Num46Line10Vers7                           nv
# Num324Line33Vers3                          nv
# Num446Line60Vers1                          nv
# Num920Line114Vers25                        nv
# Num774Line101Vers50                        nv
#
#                     VRfNx3Krud5jD43PHgxJdc_mutant_status  \
# Num46Line10Vers7                                  killed
# Num324Line33Vers3                                 killed
# Num446Line60Vers1                                 killed
# Num920Line114Vers25                             survived
# Num774Line101Vers50                               killed
#
#                     SVumrKz2o5MrZ4LmouTKTt_vs  \
# Num46Line10Vers7                           nv
# Num324Line33Vers3                          nv
# Num446Line60Vers1                          nv
# Num920Line114Vers25                        nv
# Num774Line101Vers50                         v
#
#                     SVumrKz2o5MrZ4LmouTKTt_mutant_status  \
# Num46Line10Vers7                                  killed
# Num324Line33Vers3                                 killed
# Num446Line60Vers1                                 killed
# Num920Line114Vers25                             survived
# Num774Line101Vers50                               killed
#
#                     x9GsMzyJggmJVBFwtDdWgGy_vs  \
# Num46Line10Vers7                            nv
# Num324Line33Vers3                            v
# Num446Line60Vers1                           nv
# Num920Line114Vers25                         nv
# Num774Line101Vers50                         nv
#
#                     x9GsMzyJggmJVBFwtDdWgGy_mutant_status  \
# Num46Line10Vers7                                   killed
# Num324Line33Vers3                                  killed
# Num446Line60Vers1                                  killed
# Num920Line114Vers25                              survived
# Num774Line101Vers50                                killed
#
#                     HGG3ZoLQDvNSCo68FfqnyR_vs  \
# Num46Line10Vers7                           nv
# Num324Line33Vers3                           v
# Num446Line60Vers1                          nv
# Num920Line114Vers25                        nv
# Num774Line101Vers50                        nv
#
#                     HGG3ZoLQDvNSCo68FfqnyR_mutant_status  \
# Num46Line10Vers7                                  killed
# Num324Line33Vers3                                 killed
# Num446Line60Vers1                                 killed
# Num920Line114Vers25                             survived
# Num774Line101Vers50                             survived
#
#                     HrsMvznCqa4BcUSMQxhswN_vs  \
# Num46Line10Vers7                           nv
# Num324Line33Vers3                           v
# Num446Line60Vers1                           v
# Num920Line114Vers25                        nv
# Num774Line101Vers50                         v
#
#                     HrsMvznCqa4BcUSMQxhswN_mutant_status  ...  \
# Num46Line10Vers7                                  killed  ...
# Num324Line33Vers3                                 killed  ...
# Num446Line60Vers1                                 killed  ...
# Num920Line114Vers25                             survived  ...
# Num774Line101Vers50                               killed  ...
#
#                     x4pCU9Zc9sTECRpMRFWG8CP_vs  \
# Num46Line10Vers7                            nv
# Num324Line33Vers3                            v
# Num446Line60Vers1                           nv
# Num920Line114Vers25                         nv
# Num774Line101Vers50                          v
#
#                     x4pCU9Zc9sTECRpMRFWG8CP_mutant_status  \
# Num46Line10Vers7                                   killed
# Num324Line33Vers3                                  killed
# Num446Line60Vers1                                  killed
# Num920Line114Vers25                              survived
# Num774Line101Vers50                              survived
#
#                     U5YAs6CFd4CpnrgHSMGz5H_vs  \
# Num46Line10Vers7                           nv
# Num324Line33Vers3                          nv
# Num446Line60Vers1                           v
# Num920Line114Vers25                        nv
# Num774Line101Vers50                         v
#
#                     U5YAs6CFd4CpnrgHSMGz5H_mutant_status  \
# Num46Line10Vers7                                  killed
# Num324Line33Vers3                                 killed
# Num446Line60Vers1                                 killed
# Num920Line114Vers25                               killed
# Num774Line101Vers50                               killed
#
#                     JsL4mnFBXG9PyUsRgK73KM_vs  \
# Num46Line10Vers7                           nv
# Num324Line33Vers3                           v
# Num446Line60Vers1                           v
# Num920Line114Vers25                        nv
# Num774Line101Vers50                         v
#
#                     JsL4mnFBXG9PyUsRgK73KM_mutant_status  \
# Num46Line10Vers7                                  killed
# Num324Line33Vers3                                 killed
# Num446Line60Vers1                                 killed
# Num920Line114Vers25                               killed
# Num774Line101Vers50                               killed
#
#                     Cw9zSQNxnMUAPpv63ueZMp_vs  \
# Num46Line10Vers7                           nv
# Num324Line33Vers3                           v
# Num446Line60Vers1                           v
# Num920Line114Vers25                        nv
# Num774Line101Vers50                         v
#
#                     Cw9zSQNxnMUAPpv63ueZMp_mutant_status  \
# Num46Line10Vers7                                  killed
# Num324Line33Vers3                                 killed
# Num446Line60Vers1                                 killed
# Num920Line114Vers25                               killed
# Num774Line101Vers50                               killed
#
#                     o42dQv5S9wdSGvQuBCdyuS_vs  \
# Num46Line10Vers7                           nv
# Num324Line33Vers3                           v
# Num446Line60Vers1                           v
# Num920Line114Vers25                        nv
# Num774Line101Vers50                         v
#
#                     o42dQv5S9wdSGvQuBCdyuS_mutant_status
# Num46Line10Vers7                                  killed
# Num324Line33Vers3                                 killed
# Num446Line60Vers1                                 killed
# Num920Line114Vers25                               killed
# Num774Line101Vers50                               killed
#
# [5 rows x 390 columns]

# %%
final_df
# Out:
#                      VRfNx3Krud5jD43PHgxJdc_vs  \
# Num46Line10Vers7                            nv
# Num324Line33Vers3                           nv
# Num446Line60Vers1                           nv
# Num920Line114Vers25                         nv
# Num774Line101Vers50                         nv
# ...                                        ...
# Num938Line114Vers43                         nv
# Num635Line86Vers17                           v
# Num45Line10Vers6                            nv
# Num1331Line146Vers17                         v
# Num411Line42Vers14                          nv
#
#                      VRfNx3Krud5jD43PHgxJdc_mutant_status  \
# Num46Line10Vers7                                   killed
# Num324Line33Vers3                                  killed
# Num446Line60Vers1                                  killed
# Num920Line114Vers25                              survived
# Num774Line101Vers50                                killed
# ...                                                   ...
# Num938Line114Vers43                              survived
# Num635Line86Vers17                                 killed
# Num45Line10Vers6                                   killed
# Num1331Line146Vers17                               killed
# Num411Line42Vers14                                 killed
#
#                      SVumrKz2o5MrZ4LmouTKTt_vs  \
# Num46Line10Vers7                            nv
# Num324Line33Vers3                           nv
# Num446Line60Vers1                           nv
# Num920Line114Vers25                         nv
# Num774Line101Vers50                          v
# ...                                        ...
# Num938Line114Vers43                         nv
# Num635Line86Vers17                           v
# Num45Line10Vers6                            nv
# Num1331Line146Vers17                         v
# Num411Line42Vers14                           v
#
#                      SVumrKz2o5MrZ4LmouTKTt_mutant_status  \
# Num46Line10Vers7                                   killed
# Num324Line33Vers3                                  killed
# Num446Line60Vers1                                  killed
# Num920Line114Vers25                              survived
# Num774Line101Vers50                                killed
# ...                                                   ...
# Num938Line114Vers43                              survived
# Num635Line86Vers17                                 killed
# Num45Line10Vers6                                 survived
# Num1331Line146Vers17                               killed
# Num411Line42Vers14                                 killed
#
#                      x9GsMzyJggmJVBFwtDdWgGy_vs  \
# Num46Line10Vers7                             nv
# Num324Line33Vers3                             v
# Num446Line60Vers1                            nv
# Num920Line114Vers25                          nv
# Num774Line101Vers50                          nv
# ...                                         ...
# Num938Line114Vers43                          nv
# Num635Line86Vers17                            v
# Num45Line10Vers6                             nv
# Num1331Line146Vers17                          v
# Num411Line42Vers14                            v
#
#                      x9GsMzyJggmJVBFwtDdWgGy_mutant_status  \
# Num46Line10Vers7                                    killed
# Num324Line33Vers3                                   killed
# Num446Line60Vers1                                   killed
# Num920Line114Vers25                               survived
# Num774Line101Vers50                                 killed
# ...                                                    ...
# Num938Line114Vers43                               survived
# Num635Line86Vers17                                  killed
# Num45Line10Vers6                                    killed
# Num1331Line146Vers17                                killed
# Num411Line42Vers14                                  killed
#
#                      HGG3ZoLQDvNSCo68FfqnyR_vs  \
# Num46Line10Vers7                            nv
# Num324Line33Vers3                            v
# Num446Line60Vers1                           nv
# Num920Line114Vers25                         nv
# Num774Line101Vers50                         nv
# ...                                        ...
# Num938Line114Vers43                         nv
# Num635Line86Vers17                           v
# Num45Line10Vers6                            nv
# Num1331Line146Vers17                         v
# Num411Line42Vers14                           v
#
#                      HGG3ZoLQDvNSCo68FfqnyR_mutant_status  \
# Num46Line10Vers7                                   killed
# Num324Line33Vers3                                  killed
# Num446Line60Vers1                                  killed
# Num920Line114Vers25                              survived
# Num774Line101Vers50                              survived
# ...                                                   ...
# Num938Line114Vers43                              survived
# Num635Line86Vers17                                 killed
# Num45Line10Vers6                                   killed
# Num1331Line146Vers17                               killed
# Num411Line42Vers14                                 killed
#
#                      HrsMvznCqa4BcUSMQxhswN_vs  \
# Num46Line10Vers7                            nv
# Num324Line33Vers3                            v
# Num446Line60Vers1                            v
# Num920Line114Vers25                         nv
# Num774Line101Vers50                          v
# ...                                        ...
# Num938Line114Vers43                         nv
# Num635Line86Vers17                           v
# Num45Line10Vers6                            nv
# Num1331Line146Vers17                         v
# Num411Line42Vers14                           v
#
#                      HrsMvznCqa4BcUSMQxhswN_mutant_status  ...  \
# Num46Line10Vers7                                   killed  ...
# Num324Line33Vers3                                  killed  ...
# Num446Line60Vers1                                  killed  ...
# Num920Line114Vers25                              survived  ...
# Num774Line101Vers50                                killed  ...
# ...                                                   ...  ...
# Num938Line114Vers43                              survived  ...
# Num635Line86Vers17                                 killed  ...
# Num45Line10Vers6                                 survived  ...
# Num1331Line146Vers17                               killed  ...
# Num411Line42Vers14                                 killed  ...
#
#                      x4pCU9Zc9sTECRpMRFWG8CP_vs  \
# Num46Line10Vers7                             nv
# Num324Line33Vers3                             v
# Num446Line60Vers1                            nv
# Num920Line114Vers25                          nv
# Num774Line101Vers50                           v
# ...                                         ...
# Num938Line114Vers43                          nv
# Num635Line86Vers17                            v
# Num45Line10Vers6                             nv
# Num1331Line146Vers17                          v
# Num411Line42Vers14                            v
#
#                      x4pCU9Zc9sTECRpMRFWG8CP_mutant_status  \
# Num46Line10Vers7                                    killed
# Num324Line33Vers3                                   killed
# Num446Line60Vers1                                   killed
# Num920Line114Vers25                               survived
# Num774Line101Vers50                               survived
# ...                                                    ...
# Num938Line114Vers43                               survived
# Num635Line86Vers17                                  killed
# Num45Line10Vers6                                    killed
# Num1331Line146Vers17                                killed
# Num411Line42Vers14                                  killed
#
#                      U5YAs6CFd4CpnrgHSMGz5H_vs  \
# Num46Line10Vers7                            nv
# Num324Line33Vers3                           nv
# Num446Line60Vers1                            v
# Num920Line114Vers25                         nv
# Num774Line101Vers50                          v
# ...                                        ...
# Num938Line114Vers43                         nv
# Num635Line86Vers17                           v
# Num45Line10Vers6                            nv
# Num1331Line146Vers17                         v
# Num411Line42Vers14                           v
#
#                      U5YAs6CFd4CpnrgHSMGz5H_mutant_status  \
# Num46Line10Vers7                                   killed
# Num324Line33Vers3                                  killed
# Num446Line60Vers1                                  killed
# Num920Line114Vers25                                killed
# Num774Line101Vers50                                killed
# ...                                                   ...
# Num938Line114Vers43                                killed
# Num635Line86Vers17                                 killed
# Num45Line10Vers6                                   killed
# Num1331Line146Vers17                               killed
# Num411Line42Vers14                                 killed
#
#                      JsL4mnFBXG9PyUsRgK73KM_vs  \
# Num46Line10Vers7                            nv
# Num324Line33Vers3                            v
# Num446Line60Vers1                            v
# Num920Line114Vers25                         nv
# Num774Line101Vers50                          v
# ...                                        ...
# Num938Line114Vers43                         nv
# Num635Line86Vers17                           v
# Num45Line10Vers6                            nv
# Num1331Line146Vers17                         v
# Num411Line42Vers14                           v
#
#                      JsL4mnFBXG9PyUsRgK73KM_mutant_status  \
# Num46Line10Vers7                                   killed
# Num324Line33Vers3                                  killed
# Num446Line60Vers1                                  killed
# Num920Line114Vers25                                killed
# Num774Line101Vers50                                killed
# ...                                                   ...
# Num938Line114Vers43                                killed
# Num635Line86Vers17                                 killed
# Num45Line10Vers6                                   killed
# Num1331Line146Vers17                               killed
# Num411Line42Vers14                                 killed
#
#                      Cw9zSQNxnMUAPpv63ueZMp_vs  \
# Num46Line10Vers7                            nv
# Num324Line33Vers3                            v
# Num446Line60Vers1                            v
# Num920Line114Vers25                         nv
# Num774Line101Vers50                          v
# ...                                        ...
# Num938Line114Vers43                         nv
# Num635Line86Vers17                           v
# Num45Line10Vers6                            nv
# Num1331Line146Vers17                         v
# Num411Line42Vers14                          nv
#
#                      Cw9zSQNxnMUAPpv63ueZMp_mutant_status  \
# Num46Line10Vers7                                   killed
# Num324Line33Vers3                                  killed
# Num446Line60Vers1                                  killed
# Num920Line114Vers25                                killed
# Num774Line101Vers50                                killed
# ...                                                   ...
# Num938Line114Vers43                                killed
# Num635Line86Vers17                                 killed
# Num45Line10Vers6                                   killed
# Num1331Line146Vers17                               killed
# Num411Line42Vers14                                 killed
#
#                      o42dQv5S9wdSGvQuBCdyuS_vs  \
# Num46Line10Vers7                            nv
# Num324Line33Vers3                            v
# Num446Line60Vers1                            v
# Num920Line114Vers25                         nv
# Num774Line101Vers50                          v
# ...                                        ...
# Num938Line114Vers43                         nv
# Num635Line86Vers17                           v
# Num45Line10Vers6                            nv
# Num1331Line146Vers17                         v
# Num411Line42Vers14                           v
#
#                      o42dQv5S9wdSGvQuBCdyuS_mutant_status
# Num46Line10Vers7                                   killed
# Num324Line33Vers3                                  killed
# Num446Line60Vers1                                  killed
# Num920Line114Vers25                                killed
# Num774Line101Vers50                                killed
# ...                                                   ...
# Num938Line114Vers43                                killed
# Num635Line86Vers17                                 killed
# Num45Line10Vers6                                   killed
# Num1331Line146Vers17                               killed
# Num411Line42Vers14                                 killed
#
# [135 rows x 390 columns]

# %%
import json
import pandas as pd

# Initialize an empty dictionary to hold data with test ID as keys
data_dict = {}

for paths in mutant_paths:
    folder_name = paths.split('/')[-1]
    
    HMR1_path = paths + '/final_MR1_' + folder_name + '.json'
    main_df_path = paths + '/is_equal_' + folder_name + '.csv'
    
    try:
        with open(HMR1_path, 'r') as file:
            hmr1 = json.load(file)
    except FileNotFoundError:
        print(f"File not found: {HMR1_path}")
        continue
    
    try:
        main_df = pd.read_csv(main_df_path)
    except FileNotFoundError:
        print(f"File not found: {main_df_path}")
        continue
    
    for index, row in main_df.iterrows():
        td_id = row['testID']
        
        # If test ID not in dictionary, initialize sub-dictionary
        if td_id not in data_dict:
            data_dict[td_id] = {}
        
        vs = hmr1.get(td_id, {}).get('MR1_status', 'testID not found')
        vs = 'nv' if vs == 'no-violated' else 'v' if vs != 'testID not found' else vs
        
        if row['is_output_x_equal'] and row['is_output_y_equal'] and row['is_int_x_equal'] and row['is_int_y_equal']:
            mts = 'survived'
        else:
            mts = 'killed'
        
        # Store each folder's vs and mts as separate columns under each test ID
        data_dict[td_id][folder_name + '_vs'] = vs
        data_dict[td_id][folder_name + '_mutant_status'] = mts

# Convert the dictionary into a DataFrame
final_df = pd.DataFrame.from_dict(data_dict, orient='index')

# Check the DataFrame
print(final_df.head())

# If you need to save or further process `final_df`, you can do so here
# Out:
#                         Num46Line10Vers7_vs Num46Line10Vers7_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                   nv                         killed
# SVumrKz2o5MrZ4LmouTKTt                   nv                         killed
# x9GsMzyJggmJVBFwtDdWgGy                  nv                         killed
# HGG3ZoLQDvNSCo68FfqnyR                   nv                         killed
# HrsMvznCqa4BcUSMQxhswN                   nv                         killed
#
#                         Num324Line33Vers3_vs Num324Line33Vers3_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                    nv                          killed
# SVumrKz2o5MrZ4LmouTKTt                    nv                          killed
# x9GsMzyJggmJVBFwtDdWgGy                    v                          killed
# HGG3ZoLQDvNSCo68FfqnyR                     v                          killed
# HrsMvznCqa4BcUSMQxhswN                     v                          killed
#
#                         Num446Line60Vers1_vs Num446Line60Vers1_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                    nv                          killed
# SVumrKz2o5MrZ4LmouTKTt                    nv                          killed
# x9GsMzyJggmJVBFwtDdWgGy                   nv                          killed
# HGG3ZoLQDvNSCo68FfqnyR                    nv                          killed
# HrsMvznCqa4BcUSMQxhswN                     v                          killed
#
#                         Num920Line114Vers25_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                      nv
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                      nv
#
#                         Num920Line114Vers25_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                           survived
# SVumrKz2o5MrZ4LmouTKTt                           survived
# x9GsMzyJggmJVBFwtDdWgGy                          survived
# HGG3ZoLQDvNSCo68FfqnyR                           survived
# HrsMvznCqa4BcUSMQxhswN                           survived
#
#                         Num774Line101Vers50_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                       v
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                       v
#
#                         Num774Line101Vers50_mutant_status  ...  \
# VRfNx3Krud5jD43PHgxJdc                             killed  ...
# SVumrKz2o5MrZ4LmouTKTt                             killed  ...
# x9GsMzyJggmJVBFwtDdWgGy                            killed  ...
# HGG3ZoLQDvNSCo68FfqnyR                           survived  ...
# HrsMvznCqa4BcUSMQxhswN                             killed  ...
#
#                         Num938Line114Vers43_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                      nv
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                      nv
#
#                         Num938Line114Vers43_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                           survived
# SVumrKz2o5MrZ4LmouTKTt                           survived
# x9GsMzyJggmJVBFwtDdWgGy                          survived
# HGG3ZoLQDvNSCo68FfqnyR                           survived
# HrsMvznCqa4BcUSMQxhswN                           survived
#
#                         Num635Line86Vers17_vs  \
# VRfNx3Krud5jD43PHgxJdc                      v
# SVumrKz2o5MrZ4LmouTKTt                      v
# x9GsMzyJggmJVBFwtDdWgGy                     v
# HGG3ZoLQDvNSCo68FfqnyR                      v
# HrsMvznCqa4BcUSMQxhswN                      v
#
#                         Num635Line86Vers17_mutant_status Num45Line10Vers6_vs  \
# VRfNx3Krud5jD43PHgxJdc                            killed                  nv
# SVumrKz2o5MrZ4LmouTKTt                            killed                  nv
# x9GsMzyJggmJVBFwtDdWgGy                           killed                  nv
# HGG3ZoLQDvNSCo68FfqnyR                            killed                  nv
# HrsMvznCqa4BcUSMQxhswN                            killed                  nv
#
#                         Num45Line10Vers6_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                          killed
# SVumrKz2o5MrZ4LmouTKTt                        survived
# x9GsMzyJggmJVBFwtDdWgGy                         killed
# HGG3ZoLQDvNSCo68FfqnyR                          killed
# HrsMvznCqa4BcUSMQxhswN                        survived
#
#                         Num1331Line146Vers17_vs  \
# VRfNx3Krud5jD43PHgxJdc                        v
# SVumrKz2o5MrZ4LmouTKTt                        v
# x9GsMzyJggmJVBFwtDdWgGy                       v
# HGG3ZoLQDvNSCo68FfqnyR                        v
# HrsMvznCqa4BcUSMQxhswN                        v
#
#                         Num1331Line146Vers17_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                              killed
# SVumrKz2o5MrZ4LmouTKTt                              killed
# x9GsMzyJggmJVBFwtDdWgGy                             killed
# HGG3ZoLQDvNSCo68FfqnyR                              killed
# HrsMvznCqa4BcUSMQxhswN                              killed
#
#                         Num411Line42Vers14_vs Num411Line42Vers14_mutant_status
# VRfNx3Krud5jD43PHgxJdc                     nv                           killed
# SVumrKz2o5MrZ4LmouTKTt                      v                           killed
# x9GsMzyJggmJVBFwtDdWgGy                     v                           killed
# HGG3ZoLQDvNSCo68FfqnyR                      v                           killed
# HrsMvznCqa4BcUSMQxhswN                      v                           killed
#
# [5 rows x 270 columns]

# %%
final_df
# Out:
#                         Num46Line10Vers7_vs Num46Line10Vers7_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                   nv                         killed
# SVumrKz2o5MrZ4LmouTKTt                   nv                         killed
# x9GsMzyJggmJVBFwtDdWgGy                  nv                         killed
# HGG3ZoLQDvNSCo68FfqnyR                   nv                         killed
# HrsMvznCqa4BcUSMQxhswN                   nv                         killed
# ...                                     ...                            ...
# x4pCU9Zc9sTECRpMRFWG8CP                  nv                         killed
# U5YAs6CFd4CpnrgHSMGz5H                   nv                         killed
# JsL4mnFBXG9PyUsRgK73KM                   nv                         killed
# Cw9zSQNxnMUAPpv63ueZMp                   nv                         killed
# o42dQv5S9wdSGvQuBCdyuS                   nv                         killed
#
#                         Num324Line33Vers3_vs Num324Line33Vers3_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                    nv                          killed
# SVumrKz2o5MrZ4LmouTKTt                    nv                          killed
# x9GsMzyJggmJVBFwtDdWgGy                    v                          killed
# HGG3ZoLQDvNSCo68FfqnyR                     v                          killed
# HrsMvznCqa4BcUSMQxhswN                     v                          killed
# ...                                      ...                             ...
# x4pCU9Zc9sTECRpMRFWG8CP                    v                          killed
# U5YAs6CFd4CpnrgHSMGz5H                    nv                          killed
# JsL4mnFBXG9PyUsRgK73KM                     v                          killed
# Cw9zSQNxnMUAPpv63ueZMp                     v                          killed
# o42dQv5S9wdSGvQuBCdyuS                     v                          killed
#
#                         Num446Line60Vers1_vs Num446Line60Vers1_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                    nv                          killed
# SVumrKz2o5MrZ4LmouTKTt                    nv                          killed
# x9GsMzyJggmJVBFwtDdWgGy                   nv                          killed
# HGG3ZoLQDvNSCo68FfqnyR                    nv                          killed
# HrsMvznCqa4BcUSMQxhswN                     v                          killed
# ...                                      ...                             ...
# x4pCU9Zc9sTECRpMRFWG8CP                   nv                          killed
# U5YAs6CFd4CpnrgHSMGz5H                     v                          killed
# JsL4mnFBXG9PyUsRgK73KM                     v                          killed
# Cw9zSQNxnMUAPpv63ueZMp                     v                          killed
# o42dQv5S9wdSGvQuBCdyuS                     v                          killed
#
#                         Num920Line114Vers25_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                      nv
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                      nv
# ...                                        ...
# x4pCU9Zc9sTECRpMRFWG8CP                     nv
# U5YAs6CFd4CpnrgHSMGz5H                      nv
# JsL4mnFBXG9PyUsRgK73KM                      nv
# Cw9zSQNxnMUAPpv63ueZMp                      nv
# o42dQv5S9wdSGvQuBCdyuS                      nv
#
#                         Num920Line114Vers25_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                           survived
# SVumrKz2o5MrZ4LmouTKTt                           survived
# x9GsMzyJggmJVBFwtDdWgGy                          survived
# HGG3ZoLQDvNSCo68FfqnyR                           survived
# HrsMvznCqa4BcUSMQxhswN                           survived
# ...                                                   ...
# x4pCU9Zc9sTECRpMRFWG8CP                          survived
# U5YAs6CFd4CpnrgHSMGz5H                             killed
# JsL4mnFBXG9PyUsRgK73KM                             killed
# Cw9zSQNxnMUAPpv63ueZMp                             killed
# o42dQv5S9wdSGvQuBCdyuS                             killed
#
#                         Num774Line101Vers50_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                       v
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                       v
# ...                                        ...
# x4pCU9Zc9sTECRpMRFWG8CP                      v
# U5YAs6CFd4CpnrgHSMGz5H                       v
# JsL4mnFBXG9PyUsRgK73KM                       v
# Cw9zSQNxnMUAPpv63ueZMp                       v
# o42dQv5S9wdSGvQuBCdyuS                       v
#
#                         Num774Line101Vers50_mutant_status  ...  \
# VRfNx3Krud5jD43PHgxJdc                             killed  ...
# SVumrKz2o5MrZ4LmouTKTt                             killed  ...
# x9GsMzyJggmJVBFwtDdWgGy                            killed  ...
# HGG3ZoLQDvNSCo68FfqnyR                           survived  ...
# HrsMvznCqa4BcUSMQxhswN                             killed  ...
# ...                                                   ...  ...
# x4pCU9Zc9sTECRpMRFWG8CP                          survived  ...
# U5YAs6CFd4CpnrgHSMGz5H                             killed  ...
# JsL4mnFBXG9PyUsRgK73KM                             killed  ...
# Cw9zSQNxnMUAPpv63ueZMp                             killed  ...
# o42dQv5S9wdSGvQuBCdyuS                             killed  ...
#
#                         Num938Line114Vers43_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                      nv
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                      nv
# ...                                        ...
# x4pCU9Zc9sTECRpMRFWG8CP                     nv
# U5YAs6CFd4CpnrgHSMGz5H                      nv
# JsL4mnFBXG9PyUsRgK73KM                      nv
# Cw9zSQNxnMUAPpv63ueZMp                      nv
# o42dQv5S9wdSGvQuBCdyuS                      nv
#
#                         Num938Line114Vers43_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                           survived
# SVumrKz2o5MrZ4LmouTKTt                           survived
# x9GsMzyJggmJVBFwtDdWgGy                          survived
# HGG3ZoLQDvNSCo68FfqnyR                           survived
# HrsMvznCqa4BcUSMQxhswN                           survived
# ...                                                   ...
# x4pCU9Zc9sTECRpMRFWG8CP                          survived
# U5YAs6CFd4CpnrgHSMGz5H                             killed
# JsL4mnFBXG9PyUsRgK73KM                             killed
# Cw9zSQNxnMUAPpv63ueZMp                             killed
# o42dQv5S9wdSGvQuBCdyuS                             killed
#
#                         Num635Line86Vers17_vs  \
# VRfNx3Krud5jD43PHgxJdc                      v
# SVumrKz2o5MrZ4LmouTKTt                      v
# x9GsMzyJggmJVBFwtDdWgGy                     v
# HGG3ZoLQDvNSCo68FfqnyR                      v
# HrsMvznCqa4BcUSMQxhswN                      v
# ...                                       ...
# x4pCU9Zc9sTECRpMRFWG8CP                     v
# U5YAs6CFd4CpnrgHSMGz5H                      v
# JsL4mnFBXG9PyUsRgK73KM                      v
# Cw9zSQNxnMUAPpv63ueZMp                      v
# o42dQv5S9wdSGvQuBCdyuS                      v
#
#                         Num635Line86Vers17_mutant_status Num45Line10Vers6_vs  \
# VRfNx3Krud5jD43PHgxJdc                            killed                  nv
# SVumrKz2o5MrZ4LmouTKTt                            killed                  nv
# x9GsMzyJggmJVBFwtDdWgGy                           killed                  nv
# HGG3ZoLQDvNSCo68FfqnyR                            killed                  nv
# HrsMvznCqa4BcUSMQxhswN                            killed                  nv
# ...                                                  ...                 ...
# x4pCU9Zc9sTECRpMRFWG8CP                           killed                  nv
# U5YAs6CFd4CpnrgHSMGz5H                            killed                  nv
# JsL4mnFBXG9PyUsRgK73KM                            killed                  nv
# Cw9zSQNxnMUAPpv63ueZMp                            killed                  nv
# o42dQv5S9wdSGvQuBCdyuS                            killed                  nv
#
#                         Num45Line10Vers6_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                          killed
# SVumrKz2o5MrZ4LmouTKTt                        survived
# x9GsMzyJggmJVBFwtDdWgGy                         killed
# HGG3ZoLQDvNSCo68FfqnyR                          killed
# HrsMvznCqa4BcUSMQxhswN                        survived
# ...                                                ...
# x4pCU9Zc9sTECRpMRFWG8CP                         killed
# U5YAs6CFd4CpnrgHSMGz5H                          killed
# JsL4mnFBXG9PyUsRgK73KM                          killed
# Cw9zSQNxnMUAPpv63ueZMp                          killed
# o42dQv5S9wdSGvQuBCdyuS                          killed
#
#                         Num1331Line146Vers17_vs  \
# VRfNx3Krud5jD43PHgxJdc                        v
# SVumrKz2o5MrZ4LmouTKTt                        v
# x9GsMzyJggmJVBFwtDdWgGy                       v
# HGG3ZoLQDvNSCo68FfqnyR                        v
# HrsMvznCqa4BcUSMQxhswN                        v
# ...                                         ...
# x4pCU9Zc9sTECRpMRFWG8CP                       v
# U5YAs6CFd4CpnrgHSMGz5H                        v
# JsL4mnFBXG9PyUsRgK73KM                        v
# Cw9zSQNxnMUAPpv63ueZMp                        v
# o42dQv5S9wdSGvQuBCdyuS                        v
#
#                         Num1331Line146Vers17_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                              killed
# SVumrKz2o5MrZ4LmouTKTt                              killed
# x9GsMzyJggmJVBFwtDdWgGy                             killed
# HGG3ZoLQDvNSCo68FfqnyR                              killed
# HrsMvznCqa4BcUSMQxhswN                              killed
# ...                                                    ...
# x4pCU9Zc9sTECRpMRFWG8CP                             killed
# U5YAs6CFd4CpnrgHSMGz5H                              killed
# JsL4mnFBXG9PyUsRgK73KM                              killed
# Cw9zSQNxnMUAPpv63ueZMp                              killed
# o42dQv5S9wdSGvQuBCdyuS                              killed
#
#                         Num411Line42Vers14_vs Num411Line42Vers14_mutant_status
# VRfNx3Krud5jD43PHgxJdc                     nv                           killed
# SVumrKz2o5MrZ4LmouTKTt                      v                           killed
# x9GsMzyJggmJVBFwtDdWgGy                     v                           killed
# HGG3ZoLQDvNSCo68FfqnyR                      v                           killed
# HrsMvznCqa4BcUSMQxhswN                      v                           killed
# ...                                       ...                              ...
# x4pCU9Zc9sTECRpMRFWG8CP                     v                           killed
# U5YAs6CFd4CpnrgHSMGz5H                      v                           killed
# JsL4mnFBXG9PyUsRgK73KM                      v                           killed
# Cw9zSQNxnMUAPpv63ueZMp                     nv                           killed
# o42dQv5S9wdSGvQuBCdyuS                      v                           killed
#
# [195 rows x 270 columns]

# %%
# Drop columns where all elements are equal to value_to_check
df = final_df.copy()

for column in final_df.columns:
    if df[column].eq('killed').all():
        name = column.split('_')[0]+'_vs'
        # .all() checks if all entries in the column are true for the condition
        df.drop(column, axis=1, inplace=True)
        df.drop(name, axis=1, inplace=True)

# %%
df.to_csv('mix_hmr1.csv')

# %%
df
# Out:
#                         Num46Line10Vers7_vs Num46Line10Vers7_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                   nv                         killed
# SVumrKz2o5MrZ4LmouTKTt                   nv                         killed
# x9GsMzyJggmJVBFwtDdWgGy                  nv                         killed
# HGG3ZoLQDvNSCo68FfqnyR                   nv                         killed
# HrsMvznCqa4BcUSMQxhswN                   nv                         killed
# ...                                     ...                            ...
# x4pCU9Zc9sTECRpMRFWG8CP                  nv                         killed
# U5YAs6CFd4CpnrgHSMGz5H                   nv                         killed
# JsL4mnFBXG9PyUsRgK73KM                   nv                         killed
# Cw9zSQNxnMUAPpv63ueZMp                   nv                         killed
# o42dQv5S9wdSGvQuBCdyuS                   nv                         killed
#
#                         Num920Line114Vers25_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                      nv
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                      nv
# ...                                        ...
# x4pCU9Zc9sTECRpMRFWG8CP                     nv
# U5YAs6CFd4CpnrgHSMGz5H                      nv
# JsL4mnFBXG9PyUsRgK73KM                      nv
# Cw9zSQNxnMUAPpv63ueZMp                      nv
# o42dQv5S9wdSGvQuBCdyuS                      nv
#
#                         Num920Line114Vers25_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                           survived
# SVumrKz2o5MrZ4LmouTKTt                           survived
# x9GsMzyJggmJVBFwtDdWgGy                          survived
# HGG3ZoLQDvNSCo68FfqnyR                           survived
# HrsMvznCqa4BcUSMQxhswN                           survived
# ...                                                   ...
# x4pCU9Zc9sTECRpMRFWG8CP                          survived
# U5YAs6CFd4CpnrgHSMGz5H                             killed
# JsL4mnFBXG9PyUsRgK73KM                             killed
# Cw9zSQNxnMUAPpv63ueZMp                             killed
# o42dQv5S9wdSGvQuBCdyuS                             killed
#
#                         Num774Line101Vers50_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                       v
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                       v
# ...                                        ...
# x4pCU9Zc9sTECRpMRFWG8CP                      v
# U5YAs6CFd4CpnrgHSMGz5H                       v
# JsL4mnFBXG9PyUsRgK73KM                       v
# Cw9zSQNxnMUAPpv63ueZMp                       v
# o42dQv5S9wdSGvQuBCdyuS                       v
#
#                         Num774Line101Vers50_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                             killed
# SVumrKz2o5MrZ4LmouTKTt                             killed
# x9GsMzyJggmJVBFwtDdWgGy                            killed
# HGG3ZoLQDvNSCo68FfqnyR                           survived
# HrsMvznCqa4BcUSMQxhswN                             killed
# ...                                                   ...
# x4pCU9Zc9sTECRpMRFWG8CP                          survived
# U5YAs6CFd4CpnrgHSMGz5H                             killed
# JsL4mnFBXG9PyUsRgK73KM                             killed
# Cw9zSQNxnMUAPpv63ueZMp                             killed
# o42dQv5S9wdSGvQuBCdyuS                             killed
#
#                         Num1145Line122Vers27_vs  \
# VRfNx3Krud5jD43PHgxJdc                        v
# SVumrKz2o5MrZ4LmouTKTt                        v
# x9GsMzyJggmJVBFwtDdWgGy                       v
# HGG3ZoLQDvNSCo68FfqnyR                        v
# HrsMvznCqa4BcUSMQxhswN                        v
# ...                                         ...
# x4pCU9Zc9sTECRpMRFWG8CP                      nv
# U5YAs6CFd4CpnrgHSMGz5H                       nv
# JsL4mnFBXG9PyUsRgK73KM                       nv
# Cw9zSQNxnMUAPpv63ueZMp                       nv
# o42dQv5S9wdSGvQuBCdyuS                       nv
#
#                         Num1145Line122Vers27_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                              killed
# SVumrKz2o5MrZ4LmouTKTt                              killed
# x9GsMzyJggmJVBFwtDdWgGy                             killed
# HGG3ZoLQDvNSCo68FfqnyR                              killed
# HrsMvznCqa4BcUSMQxhswN                              killed
# ...                                                    ...
# x4pCU9Zc9sTECRpMRFWG8CP                           survived
# U5YAs6CFd4CpnrgHSMGz5H                            survived
# JsL4mnFBXG9PyUsRgK73KM                            survived
# Cw9zSQNxnMUAPpv63ueZMp                            survived
# o42dQv5S9wdSGvQuBCdyuS                              killed
#
#                         Num520Line82Vers3_vs Num520Line82Vers3_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                    nv                          killed
# SVumrKz2o5MrZ4LmouTKTt                    nv                          killed
# x9GsMzyJggmJVBFwtDdWgGy                   nv                          killed
# HGG3ZoLQDvNSCo68FfqnyR                    nv                          killed
# HrsMvznCqa4BcUSMQxhswN                    nv                          killed
# ...                                      ...                             ...
# x4pCU9Zc9sTECRpMRFWG8CP                   nv                          killed
# U5YAs6CFd4CpnrgHSMGz5H                    nv                          killed
# JsL4mnFBXG9PyUsRgK73KM                    nv                          killed
# Cw9zSQNxnMUAPpv63ueZMp                    nv                          killed
# o42dQv5S9wdSGvQuBCdyuS                    nv                          killed
#
#                          ... Num302Line22Vers1_vs  \
# VRfNx3Krud5jD43PHgxJdc   ...                   nv
# SVumrKz2o5MrZ4LmouTKTt   ...                   nv
# x9GsMzyJggmJVBFwtDdWgGy  ...                   nv
# HGG3ZoLQDvNSCo68FfqnyR   ...                   nv
# HrsMvznCqa4BcUSMQxhswN   ...                   nv
# ...                      ...                  ...
# x4pCU9Zc9sTECRpMRFWG8CP  ...                   nv
# U5YAs6CFd4CpnrgHSMGz5H   ...                   nv
# JsL4mnFBXG9PyUsRgK73KM   ...                   nv
# Cw9zSQNxnMUAPpv63ueZMp   ...                   nv
# o42dQv5S9wdSGvQuBCdyuS   ...                   nv
#
#                         Num302Line22Vers1_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                         survived
# SVumrKz2o5MrZ4LmouTKTt                           killed
# x9GsMzyJggmJVBFwtDdWgGy                          killed
# HGG3ZoLQDvNSCo68FfqnyR                           killed
# HrsMvznCqa4BcUSMQxhswN                           killed
# ...                                                 ...
# x4pCU9Zc9sTECRpMRFWG8CP                          killed
# U5YAs6CFd4CpnrgHSMGz5H                           killed
# JsL4mnFBXG9PyUsRgK73KM                           killed
# Cw9zSQNxnMUAPpv63ueZMp                           killed
# o42dQv5S9wdSGvQuBCdyuS                         survived
#
#                         Num773Line101Vers49_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                       v
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                       v
# ...                                        ...
# x4pCU9Zc9sTECRpMRFWG8CP                      v
# U5YAs6CFd4CpnrgHSMGz5H                       v
# JsL4mnFBXG9PyUsRgK73KM                      nv
# Cw9zSQNxnMUAPpv63ueZMp                      nv
# o42dQv5S9wdSGvQuBCdyuS                       v
#
#                         Num773Line101Vers49_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                           survived
# SVumrKz2o5MrZ4LmouTKTt                             killed
# x9GsMzyJggmJVBFwtDdWgGy                          survived
# HGG3ZoLQDvNSCo68FfqnyR                             killed
# HrsMvznCqa4BcUSMQxhswN                             killed
# ...                                                   ...
# x4pCU9Zc9sTECRpMRFWG8CP                            killed
# U5YAs6CFd4CpnrgHSMGz5H                             killed
# JsL4mnFBXG9PyUsRgK73KM                             killed
# Cw9zSQNxnMUAPpv63ueZMp                             killed
# o42dQv5S9wdSGvQuBCdyuS                             killed
#
#                         Num938Line114Vers43_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                      nv
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                      nv
# ...                                        ...
# x4pCU9Zc9sTECRpMRFWG8CP                     nv
# U5YAs6CFd4CpnrgHSMGz5H                      nv
# JsL4mnFBXG9PyUsRgK73KM                      nv
# Cw9zSQNxnMUAPpv63ueZMp                      nv
# o42dQv5S9wdSGvQuBCdyuS                      nv
#
#                         Num938Line114Vers43_mutant_status Num45Line10Vers6_vs  \
# VRfNx3Krud5jD43PHgxJdc                           survived                  nv
# SVumrKz2o5MrZ4LmouTKTt                           survived                  nv
# x9GsMzyJggmJVBFwtDdWgGy                          survived                  nv
# HGG3ZoLQDvNSCo68FfqnyR                           survived                  nv
# HrsMvznCqa4BcUSMQxhswN                           survived                  nv
# ...                                                   ...                 ...
# x4pCU9Zc9sTECRpMRFWG8CP                          survived                  nv
# U5YAs6CFd4CpnrgHSMGz5H                             killed                  nv
# JsL4mnFBXG9PyUsRgK73KM                             killed                  nv
# Cw9zSQNxnMUAPpv63ueZMp                             killed                  nv
# o42dQv5S9wdSGvQuBCdyuS                             killed                  nv
#
#                         Num45Line10Vers6_mutant_status Num411Line42Vers14_vs  \
# VRfNx3Krud5jD43PHgxJdc                          killed                    nv
# SVumrKz2o5MrZ4LmouTKTt                        survived                     v
# x9GsMzyJggmJVBFwtDdWgGy                         killed                     v
# HGG3ZoLQDvNSCo68FfqnyR                          killed                     v
# HrsMvznCqa4BcUSMQxhswN                        survived                     v
# ...                                                ...                   ...
# x4pCU9Zc9sTECRpMRFWG8CP                         killed                     v
# U5YAs6CFd4CpnrgHSMGz5H                          killed                     v
# JsL4mnFBXG9PyUsRgK73KM                          killed                     v
# Cw9zSQNxnMUAPpv63ueZMp                          killed                    nv
# o42dQv5S9wdSGvQuBCdyuS                          killed                     v
#
#                         Num411Line42Vers14_mutant_status
# VRfNx3Krud5jD43PHgxJdc                            killed
# SVumrKz2o5MrZ4LmouTKTt                            killed
# x9GsMzyJggmJVBFwtDdWgGy                           killed
# HGG3ZoLQDvNSCo68FfqnyR                            killed
# HrsMvznCqa4BcUSMQxhswN                            killed
# ...                                                  ...
# x4pCU9Zc9sTECRpMRFWG8CP                           killed
# U5YAs6CFd4CpnrgHSMGz5H                            killed
# JsL4mnFBXG9PyUsRgK73KM                            killed
# Cw9zSQNxnMUAPpv63ueZMp                            killed
# o42dQv5S9wdSGvQuBCdyuS                            killed
#
# [195 rows x 168 columns]

# %%
df.describe(include='all')
# Out:
#        Num46Line10Vers7_vs Num46Line10Vers7_mutant_status  \
# count                  195                            195
# unique                   1                              2
# top                     nv                         killed
# freq                   195                            187
#
#        Num920Line114Vers25_vs Num920Line114Vers25_mutant_status  \
# count                     195                               195
# unique                      2                                 2
# top                        nv                            killed
# freq                      189                               120
#
#        Num774Line101Vers50_vs Num774Line101Vers50_mutant_status  \
# count                     195                               195
# unique                      2                                 2
# top                         v                            killed
# freq                      110                               175
#
#        Num1145Line122Vers27_vs Num1145Line122Vers27_mutant_status  \
# count                      195                                195
# unique                       2                                  2
# top                         nv                             killed
# freq                       180                                100
#
#        Num520Line82Vers3_vs Num520Line82Vers3_mutant_status  ...  \
# count                   195                             195  ...
# unique                    1                               2  ...
# top                      nv                          killed  ...
# freq                    195                             189  ...
#
#        Num302Line22Vers1_vs Num302Line22Vers1_mutant_status  \
# count                   195                             195
# unique                    1                               2
# top                      nv                          killed
# freq                    195                             121
#
#        Num773Line101Vers49_vs Num773Line101Vers49_mutant_status  \
# count                     195                               195
# unique                      3                                 2
# top                         v                            killed
# freq                      104                               176
#
#        Num938Line114Vers43_vs Num938Line114Vers43_mutant_status  \
# count                     195                               195
# unique                      2                                 2
# top                        nv                            killed
# freq                      189                               120
#
#        Num45Line10Vers6_vs Num45Line10Vers6_mutant_status  \
# count                  195                            195
# unique                   2                              2
# top                     nv                         killed
# freq                   194                            187
#
#        Num411Line42Vers14_vs Num411Line42Vers14_mutant_status
# count                    195                              195
# unique                     2                                2
# top                        v                           killed
# freq                     142                              183
#
# [4 rows x 168 columns]

# %%
168/2
# Out:
# 84.0

# %%
df
# Out:
#                         Num46Line10Vers7_vs Num46Line10Vers7_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                   nv                         killed
# SVumrKz2o5MrZ4LmouTKTt                   nv                         killed
# x9GsMzyJggmJVBFwtDdWgGy                  nv                         killed
# HGG3ZoLQDvNSCo68FfqnyR                   nv                         killed
# HrsMvznCqa4BcUSMQxhswN                   nv                         killed
# ...                                     ...                            ...
# x4pCU9Zc9sTECRpMRFWG8CP                  nv                         killed
# U5YAs6CFd4CpnrgHSMGz5H                   nv                         killed
# JsL4mnFBXG9PyUsRgK73KM                   nv                         killed
# Cw9zSQNxnMUAPpv63ueZMp                   nv                         killed
# o42dQv5S9wdSGvQuBCdyuS                   nv                         killed
#
#                         Num920Line114Vers25_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                      nv
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                      nv
# ...                                        ...
# x4pCU9Zc9sTECRpMRFWG8CP                     nv
# U5YAs6CFd4CpnrgHSMGz5H                      nv
# JsL4mnFBXG9PyUsRgK73KM                      nv
# Cw9zSQNxnMUAPpv63ueZMp                      nv
# o42dQv5S9wdSGvQuBCdyuS                      nv
#
#                         Num920Line114Vers25_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                           survived
# SVumrKz2o5MrZ4LmouTKTt                           survived
# x9GsMzyJggmJVBFwtDdWgGy                          survived
# HGG3ZoLQDvNSCo68FfqnyR                           survived
# HrsMvznCqa4BcUSMQxhswN                           survived
# ...                                                   ...
# x4pCU9Zc9sTECRpMRFWG8CP                          survived
# U5YAs6CFd4CpnrgHSMGz5H                             killed
# JsL4mnFBXG9PyUsRgK73KM                             killed
# Cw9zSQNxnMUAPpv63ueZMp                             killed
# o42dQv5S9wdSGvQuBCdyuS                             killed
#
#                         Num774Line101Vers50_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                       v
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                       v
# ...                                        ...
# x4pCU9Zc9sTECRpMRFWG8CP                      v
# U5YAs6CFd4CpnrgHSMGz5H                       v
# JsL4mnFBXG9PyUsRgK73KM                       v
# Cw9zSQNxnMUAPpv63ueZMp                       v
# o42dQv5S9wdSGvQuBCdyuS                       v
#
#                         Num774Line101Vers50_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                             killed
# SVumrKz2o5MrZ4LmouTKTt                             killed
# x9GsMzyJggmJVBFwtDdWgGy                            killed
# HGG3ZoLQDvNSCo68FfqnyR                           survived
# HrsMvznCqa4BcUSMQxhswN                             killed
# ...                                                   ...
# x4pCU9Zc9sTECRpMRFWG8CP                          survived
# U5YAs6CFd4CpnrgHSMGz5H                             killed
# JsL4mnFBXG9PyUsRgK73KM                             killed
# Cw9zSQNxnMUAPpv63ueZMp                             killed
# o42dQv5S9wdSGvQuBCdyuS                             killed
#
#                         Num1145Line122Vers27_vs  \
# VRfNx3Krud5jD43PHgxJdc                        v
# SVumrKz2o5MrZ4LmouTKTt                        v
# x9GsMzyJggmJVBFwtDdWgGy                       v
# HGG3ZoLQDvNSCo68FfqnyR                        v
# HrsMvznCqa4BcUSMQxhswN                        v
# ...                                         ...
# x4pCU9Zc9sTECRpMRFWG8CP                      nv
# U5YAs6CFd4CpnrgHSMGz5H                       nv
# JsL4mnFBXG9PyUsRgK73KM                       nv
# Cw9zSQNxnMUAPpv63ueZMp                       nv
# o42dQv5S9wdSGvQuBCdyuS                       nv
#
#                         Num1145Line122Vers27_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                              killed
# SVumrKz2o5MrZ4LmouTKTt                              killed
# x9GsMzyJggmJVBFwtDdWgGy                             killed
# HGG3ZoLQDvNSCo68FfqnyR                              killed
# HrsMvznCqa4BcUSMQxhswN                              killed
# ...                                                    ...
# x4pCU9Zc9sTECRpMRFWG8CP                           survived
# U5YAs6CFd4CpnrgHSMGz5H                            survived
# JsL4mnFBXG9PyUsRgK73KM                            survived
# Cw9zSQNxnMUAPpv63ueZMp                            survived
# o42dQv5S9wdSGvQuBCdyuS                              killed
#
#                         Num520Line82Vers3_vs Num520Line82Vers3_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                    nv                          killed
# SVumrKz2o5MrZ4LmouTKTt                    nv                          killed
# x9GsMzyJggmJVBFwtDdWgGy                   nv                          killed
# HGG3ZoLQDvNSCo68FfqnyR                    nv                          killed
# HrsMvznCqa4BcUSMQxhswN                    nv                          killed
# ...                                      ...                             ...
# x4pCU9Zc9sTECRpMRFWG8CP                   nv                          killed
# U5YAs6CFd4CpnrgHSMGz5H                    nv                          killed
# JsL4mnFBXG9PyUsRgK73KM                    nv                          killed
# Cw9zSQNxnMUAPpv63ueZMp                    nv                          killed
# o42dQv5S9wdSGvQuBCdyuS                    nv                          killed
#
#                          ... Num302Line22Vers1_vs  \
# VRfNx3Krud5jD43PHgxJdc   ...                   nv
# SVumrKz2o5MrZ4LmouTKTt   ...                   nv
# x9GsMzyJggmJVBFwtDdWgGy  ...                   nv
# HGG3ZoLQDvNSCo68FfqnyR   ...                   nv
# HrsMvznCqa4BcUSMQxhswN   ...                   nv
# ...                      ...                  ...
# x4pCU9Zc9sTECRpMRFWG8CP  ...                   nv
# U5YAs6CFd4CpnrgHSMGz5H   ...                   nv
# JsL4mnFBXG9PyUsRgK73KM   ...                   nv
# Cw9zSQNxnMUAPpv63ueZMp   ...                   nv
# o42dQv5S9wdSGvQuBCdyuS   ...                   nv
#
#                         Num302Line22Vers1_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                         survived
# SVumrKz2o5MrZ4LmouTKTt                           killed
# x9GsMzyJggmJVBFwtDdWgGy                          killed
# HGG3ZoLQDvNSCo68FfqnyR                           killed
# HrsMvznCqa4BcUSMQxhswN                           killed
# ...                                                 ...
# x4pCU9Zc9sTECRpMRFWG8CP                          killed
# U5YAs6CFd4CpnrgHSMGz5H                           killed
# JsL4mnFBXG9PyUsRgK73KM                           killed
# Cw9zSQNxnMUAPpv63ueZMp                           killed
# o42dQv5S9wdSGvQuBCdyuS                         survived
#
#                         Num773Line101Vers49_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                       v
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                       v
# ...                                        ...
# x4pCU9Zc9sTECRpMRFWG8CP                      v
# U5YAs6CFd4CpnrgHSMGz5H                       v
# JsL4mnFBXG9PyUsRgK73KM                      nv
# Cw9zSQNxnMUAPpv63ueZMp                      nv
# o42dQv5S9wdSGvQuBCdyuS                       v
#
#                         Num773Line101Vers49_mutant_status  \
# VRfNx3Krud5jD43PHgxJdc                           survived
# SVumrKz2o5MrZ4LmouTKTt                             killed
# x9GsMzyJggmJVBFwtDdWgGy                          survived
# HGG3ZoLQDvNSCo68FfqnyR                             killed
# HrsMvznCqa4BcUSMQxhswN                             killed
# ...                                                   ...
# x4pCU9Zc9sTECRpMRFWG8CP                            killed
# U5YAs6CFd4CpnrgHSMGz5H                             killed
# JsL4mnFBXG9PyUsRgK73KM                             killed
# Cw9zSQNxnMUAPpv63ueZMp                             killed
# o42dQv5S9wdSGvQuBCdyuS                             killed
#
#                         Num938Line114Vers43_vs  \
# VRfNx3Krud5jD43PHgxJdc                      nv
# SVumrKz2o5MrZ4LmouTKTt                      nv
# x9GsMzyJggmJVBFwtDdWgGy                     nv
# HGG3ZoLQDvNSCo68FfqnyR                      nv
# HrsMvznCqa4BcUSMQxhswN                      nv
# ...                                        ...
# x4pCU9Zc9sTECRpMRFWG8CP                     nv
# U5YAs6CFd4CpnrgHSMGz5H                      nv
# JsL4mnFBXG9PyUsRgK73KM                      nv
# Cw9zSQNxnMUAPpv63ueZMp                      nv
# o42dQv5S9wdSGvQuBCdyuS                      nv
#
#                         Num938Line114Vers43_mutant_status Num45Line10Vers6_vs  \
# VRfNx3Krud5jD43PHgxJdc                           survived                  nv
# SVumrKz2o5MrZ4LmouTKTt                           survived                  nv
# x9GsMzyJggmJVBFwtDdWgGy                          survived                  nv
# HGG3ZoLQDvNSCo68FfqnyR                           survived                  nv
# HrsMvznCqa4BcUSMQxhswN                           survived                  nv
# ...                                                   ...                 ...
# x4pCU9Zc9sTECRpMRFWG8CP                          survived                  nv
# U5YAs6CFd4CpnrgHSMGz5H                             killed                  nv
# JsL4mnFBXG9PyUsRgK73KM                             killed                  nv
# Cw9zSQNxnMUAPpv63ueZMp                             killed                  nv
# o42dQv5S9wdSGvQuBCdyuS                             killed                  nv
#
#                         Num45Line10Vers6_mutant_status Num411Line42Vers14_vs  \
# VRfNx3Krud5jD43PHgxJdc                          killed                    nv
# SVumrKz2o5MrZ4LmouTKTt                        survived                     v
# x9GsMzyJggmJVBFwtDdWgGy                         killed                     v
# HGG3ZoLQDvNSCo68FfqnyR                          killed                     v
# HrsMvznCqa4BcUSMQxhswN                        survived                     v
# ...                                                ...                   ...
# x4pCU9Zc9sTECRpMRFWG8CP                         killed                     v
# U5YAs6CFd4CpnrgHSMGz5H                          killed                     v
# JsL4mnFBXG9PyUsRgK73KM                          killed                     v
# Cw9zSQNxnMUAPpv63ueZMp                          killed                    nv
# o42dQv5S9wdSGvQuBCdyuS                          killed                     v
#
#                         Num411Line42Vers14_mutant_status
# VRfNx3Krud5jD43PHgxJdc                            killed
# SVumrKz2o5MrZ4LmouTKTt                            killed
# x9GsMzyJggmJVBFwtDdWgGy                           killed
# HGG3ZoLQDvNSCo68FfqnyR                            killed
# HrsMvznCqa4BcUSMQxhswN                            killed
# ...                                                  ...
# x4pCU9Zc9sTECRpMRFWG8CP                           killed
# U5YAs6CFd4CpnrgHSMGz5H                            killed
# JsL4mnFBXG9PyUsRgK73KM                            killed
# Cw9zSQNxnMUAPpv63ueZMp                            killed
# o42dQv5S9wdSGvQuBCdyuS                            killed
#
# [195 rows x 168 columns]

# %%
vs_columns = [col for col in df.columns if col.endswith('_vs')]

# Select only the '_vs' columns from the DataFrame
vs_data = df[vs_columns]

# Plotting
# Count the occurrences of each value in each '_vs' column
value_counts = vs_data.apply(pd.Series.value_counts).fillna(0)

# Create a bar plot for each '_vs' column
fig, axes = plt.subplots(nrows=len(vs_columns), figsize=(10, 5 * len(vs_columns)))

for i, column in enumerate(vs_columns):
    value_counts[column].plot(kind='bar', ax=axes[i], title=column)

plt.tight_layout()
plt.show()

# %%
vs_columns = [col for col in df.columns if col.endswith('_vs')]

# Select only the '_vs' columns from the DataFrame
vs_data = df[vs_columns]

# Aggregate counts of 'v' and 'nv' across all selected columns
total_counts = vs_data.apply(pd.Series.value_counts).sum(axis=1)

# Plotting
plt.figure(figsize=(10, 6))
total_counts.plot(kind='bar', color=['blue', 'orange'])
plt.title('Aggregate Counts of "v" (Violated) and "nv" (Not Violated) Across All Tests')
plt.xlabel('Status')
plt.ylabel('Count')
plt.xticks(rotation=0)  # Rotate labels to horizontal
plt.show()

# %%
# Filter columns that end with '_vs'
vs_columns = [col for col in df.columns if col.endswith('_vs')]

# Select only the '_vs' columns from the DataFrame
vs_data = df[vs_columns]

# Calculate counts of 'v' and 'nv' for each column
value_counts = vs_data.apply(pd.Series.value_counts).fillna(0).T  # Transpose to make columns suitable for plotting

# Plotting
fig, ax = plt.subplots(figsize=(14, 8))  # Set figure size for better readability

# Plot each category ('v' and 'nv') side by side
value_counts[['v', 'nv']].plot(kind='bar', ax=ax, color=['red', 'green'])

plt.title('Counts of "v" (Violated) and "nv" (Not Violated) for Each Test')
plt.xlabel('Test Identifier')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.legend(title='Status')

plt.tight_layout()
plt.show()

# %%
# Filter columns that end with '_vs'
vs_columns = [col for col in df.columns if col.endswith('_vs')]

# Select only the '_vs' columns from the DataFrame
vs_data = df[vs_columns]

# Calculate counts of 'v' and 'nv' for each column
value_counts = vs_data.apply(pd.Series.value_counts).fillna(0).T  # Transpose to make columns suitable for plotting

# Generate new x-axis labels as sequential numbers
x_labels = range(1, len(vs_columns) + 1)

# Plotting
fig, ax = plt.subplots(figsize=(20, 4))
colors = ['#bdc3c7', '#7f8c8d']  # Light gray and dark gray
 #

# Plot each category ('v' and 'nv') stacked
value_counts['v'].plot(kind='bar', ax=ax, color=colors[1], label='Violated (v)', width=0.8)
value_counts['nv'].plot(kind='bar', ax=ax, color=colors[0],  bottom=value_counts['v'], label='Not Violated (nv)', width=0.8)


plt.title('Stacked Counts of "v" (Violated) and "nv" (Not Violated) for Each Test')
plt.xlabel('Test Identifier Number')
plt.ylabel('Count')
plt.xticks(ticks=range(len(vs_columns)), labels=x_labels, rotation=0)  # Set custom x-axis labels
plt.legend(title='Status')

plt.tight_layout()
pdf_path = 'HMR1_vs.pdf'
fig.savefig(pdf_path, format='pdf')
plt.show()

# %%
# Filter columns that end with '_vs'
status_columns = [col for col in df.columns if col.endswith('_mutant_status')]

# Select only the '_vs' columns from the DataFrame
status_data = df[status_columns]

# Calculate counts of 'v' and 'nv' for each column
status_counts = status_data.apply(pd.Series.value_counts).fillna(0).T  # Transpose to make columns suitable for plotting

# Generate new x-axis labels as sequential numbers
x_labels = range(1, len(vs_columns) + 1)

# Plotting
fig, ax = plt.subplots(figsize=(20, 4))  # Set figure size for better readability

colors = ['#bdc3c7', '#7f8c8d']  # Light gray and dark gray
patterns = ['/', '.']  # Different hatch patterns

# Plot each category ('killed' and 'survived') stacked with patterns
status_counts['killed'].plot(kind='bar', ax=ax, color=colors[1], hatch=patterns[1], label='Killed', width=0.8)
status_counts['survived'].plot(kind='bar', ax=ax, color=colors[0], hatch=patterns[0], bottom=status_counts['killed'], label='Survived', width=0.8)

plt.title('Stacked Counts of "Killed" and "Survived" for Each Test in Grayscale')
plt.xlabel('Test Identifier Number')
plt.ylabel('Count')
plt.xticks(ticks=range(len(status_columns)), labels=x_labels, rotation=0)  # Set custom x-axis labels with no rotation
plt.legend(title='Status')
plt.tight_layout()  # Adjust layout to make more space

pdf_path = 'HMR1_ms.pdf'
fig.savefig(pdf_path, format='pdf')
plt.show()

# %%
# Filter columns that end with '_vs' and '_mutant_status'
vs_columns = [col for col in df.columns if col.endswith('_vs')]
status_columns = [col for col in df.columns if col.endswith('_mutant_status')]

# Select only the relevant columns from the DataFrame
vs_data = df[vs_columns]
status_data = df[status_columns]

# Calculate counts of 'v' and 'nv' for each vs column, and 'killed' and 'survived' for each status column
vs_value_counts = vs_data.apply(pd.Series.value_counts).fillna(0).T  # Transpose for easy calculation
status_value_counts = status_data.apply(pd.Series.value_counts).fillna(0).T  # Transpose for easy calculation

# Calculate proportions
vs_proportions = vs_value_counts.apply(lambda x: x / x.sum(), axis=1)
status_proportions = status_value_counts.apply(lambda x: x / x.sum(), axis=1)

# Creating a combined DataFrame for summary
summary_df = pd.DataFrame({
    'Test Identifier': vs_proportions.index.tolist() + status_proportions.index.tolist(),
    'Violated Proportion': vs_proportions['v'].tolist() + [None] * len(status_proportions),  # Only for vs columns
    'Not Violated Proportion': vs_proportions['nv'].tolist() + [None] * len(status_proportions),  # Only for vs columns
    'Killed Proportion': [None] * len(vs_proportions) + status_proportions['killed'].tolist(),  # Only for status columns
    'Survived Proportion': [None] * len(vs_proportions) + status_proportions['survived'].tolist()  # Only for status columns
})

summary_df
# Out:
#                        Test Identifier  Violated Proportion  \
# 0                  Num46Line10Vers7_vs             0.000000
# 1               Num920Line114Vers25_vs             0.030769
# 2               Num774Line101Vers50_vs             0.564103
# 3              Num1145Line122Vers27_vs             0.076923
# 4                 Num520Line82Vers3_vs             0.000000
# ..                                 ...                  ...
# 163    Num302Line22Vers1_mutant_status                  NaN
# 164  Num773Line101Vers49_mutant_status                  NaN
# 165  Num938Line114Vers43_mutant_status                  NaN
# 166     Num45Line10Vers6_mutant_status                  NaN
# 167   Num411Line42Vers14_mutant_status                  NaN
#
#      Not Violated Proportion  Killed Proportion  Survived Proportion
# 0                   1.000000                NaN                  NaN
# 1                   0.969231                NaN                  NaN
# 2                   0.435897                NaN                  NaN
# 3                   0.923077                NaN                  NaN
# 4                   1.000000                NaN                  NaN
# ..                       ...                ...                  ...
# 163                      NaN           0.620513             0.379487
# 164                      NaN           0.902564             0.097436
# 165                      NaN           0.615385             0.384615
# 166                      NaN           0.958974             0.041026
# 167                      NaN           0.938462             0.061538
#
# [168 rows x 5 columns]
